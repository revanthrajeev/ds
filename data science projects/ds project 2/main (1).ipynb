# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Olympics.csv")

# %% [markdown]
# ## 1. Retrieve all records from the Olympics table

# %%
df   # first and last five rows
# Out:
#     id                                name sex  age  height  weight  \
# 0    1                           A Dijiang   M   24   180.0    80.0
# 1    2                            A Lamusi   M   23   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M   24     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M   34     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F   21   185.0    82.0
# ..  ..                                 ...  ..  ...     ...     ...
# 95  32                Olav Augunson Aarnes   M   23     NaN     NaN
# 96  33                 Mika Lauri Aarnikka   M   24   187.0    76.0
# 97  33                 Mika Lauri Aarnikka   M   28   187.0    76.0
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M   30   187.0    76.0
# 99  35              Dagfinn Sverre Aarskog   M   24   190.0    98.0
#
#               team  noc        games  year  season       city          sport  \
# 0            China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1            China  CHN  2012 Summer  2012  Summer     London           Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4      Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
# ..             ...  ...          ...   ...     ...        ...            ...
# 95          Norway  NOR  1912 Summer  1912  Summer  Stockholm      Athletics
# 96         Finland  FIN  1992 Summer  1992  Summer  Barcelona        Sailing
# 97         Finland  FIN  1996 Summer  1996  Summer    Atlanta        Sailing
# 98          France  FRA  2012 Summer  2012  Summer     London      Athletics
# 99          Norway  NOR  1998 Winter  1998  Winter     Nagano      Bobsleigh
#
#                                event medal
# 0        Basketball Men's Basketball   NaN
# 1       Judo Men's Extra-Lightweight   NaN
# 2            Football Men's Football   NaN
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 4   Speed Skating Women's 500 metres   NaN
# ..                               ...   ...
# 95         Athletics Men's High Jump   NaN
# 96   Sailing Men's Two Person Dinghy   NaN
# 97   Sailing Men's Two Person Dinghy   NaN
# 98    "Athletics Men's 1,500 metres"   NaN
# 99              Bobsleigh Men's Four   NaN
#
# [100 rows x 15 columns]

# %% [markdown]
# ## 2. Retrieve only the Athlete names and the Medals they won

# %%
df["medal"].isnull().sum()   # in medal we have 79 null values, which means the players have not won any medal
# Out:
# 79

# %%
# so replacing null value with None
df["medal"] = df["medal"].replace(np.nan, "None", regex = False)

# %% [markdown]
# ### Answer - 2

# %%
pd.concat([ df["name"], df["medal"] ], axis = 1)
# Out:
#                                   name medal
# 0                            A Dijiang  None
# 1                             A Lamusi  None
# 2                  Gunnar Nielsen Aaby  None
# 3                 Edgar Lindenau Aabye  Gold
# 4             Christine Jacoba Aaftink  None
# ..                                 ...   ...
# 95                Olav Augunson Aarnes  None
# 96                 Mika Lauri Aarnikka  None
# 97                 Mika Lauri Aarnikka  None
# 98  Jamale (Djamel-) Aarrass (Ahrass-)  None
# 99              Dagfinn Sverre Aarskog  None
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 3. Count the total number of athletes in the dataset.

# %%
df["name"].unique()
# Out:
# array(['A Dijiang', 'A Lamusi', 'Gunnar Nielsen Aaby',
#        'Edgar Lindenau Aabye', 'Christine Jacoba Aaftink',
#        'Per Knut Aaland', 'John Aalberg',
#        'Cornelia \\Cor\\" Aalten (-Strannood)"', 'Antti Sami Aalto',
#        'Einar Ferdinand \\Einari\\" Aalto"', 'Jorma Ilmari Aalto',
#        'Jyri Tapani Aalto', 'Minna Maarit Aalto',
#        'Pirjo Hannele Aalto (Mattila-)', 'Arvo Ossian Aaltonen',
#        'Juhamatti Tapio Aaltonen', 'Paavo Johannes Aaltonen',
#        'Timo Antero Aaltonen', 'Win Valdemar Aaltonen',
#        'Kjetil Andr Aamodt', 'Ragnhild Margrethe Aamodt', 'Andreea Aanei',
#        'Fritz Aanes', 'Nils Egil Aaness', 'Alf Lied Aanning',
#        'Agnes Erika Aanonsen (-Eyde)', 'Johan Aantjes',
#        'Jan-Erik Aarberg', 'Willemien Aardenburg', 'Pepijn Aardewijn',
#        'Evald rma (rman-)', 'Olav Augunson Aarnes', 'Mika Lauri Aarnikka',
#        'Jamale (Djamel-) Aarrass (Ahrass-)', 'Dagfinn Sverre Aarskog'],
#       dtype=object)

# %% [markdown]
# ### Answer - 3

# %%
np.size(df["name"].unique())
# Out:
# 35

# %% [markdown]
# ## 4. Find all records of athletes who won a Gold medal

# %%
dfGold = df.loc[df["medal"] == "Gold"]  # players who won gold medal
dfGold.head()
# Out:
#     id                     name sex  age  height  weight            team  noc  \
# 3    4     Edgar Lindenau Aabye   M   34     NaN     NaN  Denmark/Sweden  DEN
# 42  17  Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland  FIN
# 44  17  Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland  FIN
# 48  17  Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland  FIN
# 60  20       Kjetil Andr Aamodt   M   20   176.0    85.0          Norway  NOR
#
#           games  year  season         city          sport  \
# 3   1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  1948 Summer  1948  Summer       London     Gymnastics
# 44  1948 Summer  1948  Summer       London     Gymnastics
# 48  1948 Summer  1948  Summer       London     Gymnastics
# 60  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                event medal
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 42  Gymnastics Men's Team All-Around  Gold
# 44      Gymnastics Men's Horse Vault  Gold
# 48  Gymnastics Men's Pommelled Horse  Gold
# 60       Alpine Skiing Men's Super G  Gold

# %%
dfGold.name.count()
# Out:
# 9

# %%
dfGold.name.value_counts()  # Count of athlete who won gold medal
# Out:
# name
# Kjetil Andr Aamodt           4
# Paavo Johannes Aaltonen      3
# Edgar Lindenau Aabye         1
# Ragnhild Margrethe Aamodt    1
# Name: count, dtype: int64

# %% [markdown]
# ## 5. List all athletes who won Silver, ordered by the Year they won it.

# %%
dfSilver = df.loc[df["medal"] == "Silver"]
dfSilver
# Out:
#     id                name sex  age  height  weight         team  noc  \
# 63  20  Kjetil Andr Aamodt   M   22   176.0    85.0       Norway  NOR
# 67  20  Kjetil Andr Aamodt   M   22   176.0    85.0       Norway  NOR
# 86  25    Alf Lied Aanning   M   24     NaN     NaN       Norway  NOR
# 92  30    Pepijn Aardewijn   M   26   189.0    72.0  Netherlands  NED
#
#           games  year  season         city          sport  \
# 63  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 67  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 86  1920 Summer  1920  Summer    Antwerpen     Gymnastics
# 92  1996 Summer  1996  Summer      Atlanta         Rowing
#
#                                               event   medal
# 63                     Alpine Skiing Men's Downhill  Silver
# 67                     Alpine Skiing Men's Combined  Silver
# 86  "Gymnastics Men's Team All-Around, Free System"  Silver
# 92           Rowing Men's Lightweight Double Sculls  Silver

# %%
df1 = pd.concat([dfSilver["name"], dfSilver["year"], dfSilver["medal"]], axis = 1)
df1
# Out:
#                   name  year   medal
# 63  Kjetil Andr Aamodt  1994  Silver
# 67  Kjetil Andr Aamodt  1994  Silver
# 86    Alf Lied Aanning  1920  Silver
# 92    Pepijn Aardewijn  1996  Silver

# %%
df1 = df1.set_index("year")

# %% [markdown]
# ### Answer - 5

# %%
df1.sort_index()  # list of all the athlete who won Silver medal sorted by year
# Out:
#                     name   medal
# year
# 1920    Alf Lied Aanning  Silver
# 1994  Kjetil Andr Aamodt  Silver
# 1994  Kjetil Andr Aamodt  Silver
# 1996    Pepijn Aardewijn  Silver

# %% [markdown]
# ## 6. Count how many Gold, Silver, and Bronze medals each country has won.

# %%
df["team"].unique()
# Out:
# array(['China', 'Denmark', 'Denmark/Sweden', 'Netherlands',
#        'United States', 'Finland', 'Norway', 'Romania', 'Estonia',
#        'France'], dtype=object)

# %%
dfMedal = df.groupby(["team", "medal"]).size().unstack(fill_value=0 )

# %%
dfMedal.drop(labels=["None"], inplace=True, axis = 1)

# %% [markdown]
# ### Answer - 6

# %%
dfMedal
# Out:
# medal           Bronze  Gold  Silver
# team
# China                0     0       0
# Denmark              0     0       0
# Denmark/Sweden       0     1       0
# Estonia              0     0       0
# Finland              5     3       0
# France               0     0       0
# Netherlands          1     0       1
# Norway               2     5       3
# Romania              0     0       0
# United States        0     0       0

# %% [markdown]
# ## 7. Identify countries that have won more than 50 Gold medals.

# %%
dfMedal
# Out:
# medal           Bronze  Gold  Silver
# team
# China                0     0       0
# Denmark              0     0       0
# Denmark/Sweden       0     1       0
# Estonia              0     0       0
# Finland              5     3       0
# France               0     0       0
# Netherlands          1     0       1
# Norway               2     5       3
# Romania              0     0       0
# United States        0     0       0

# %% [markdown]
# From above data we can clearly see that no country has won gold medal more than 50

# %% [markdown]
# ## 8. Find the athlete who has won the most medals

# %%
df2 = df.loc[df["medal"] != "None"]
df2
# Out:
#     id                       name sex  age  height  weight            team  \
# 3    4       Edgar Lindenau Aabye   M   34     NaN     NaN  Denmark/Sweden
# 37  15       Arvo Ossian Aaltonen   M   30     NaN     NaN         Finland
# 38  15       Arvo Ossian Aaltonen   M   30     NaN     NaN         Finland
# 40  16   Juhamatti Tapio Aaltonen   M   28   184.0    85.0         Finland
# 41  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 42  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 44  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 48  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 50  17    Paavo Johannes Aaltonen   M   32   175.0    64.0         Finland
# 60  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 61  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 63  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 64  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 67  20         Kjetil Andr Aamodt   M   22   176.0    85.0          Norway
# 73  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 76  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 78  20         Kjetil Andr Aamodt   M   34   176.0    85.0          Norway
# 79  21  Ragnhild Margrethe Aamodt   F   27   163.0     NaN          Norway
# 86  25           Alf Lied Aanning   M   24     NaN     NaN          Norway
# 91  29       Willemien Aardenburg   F   22     NaN     NaN     Netherlands
# 92  30           Pepijn Aardewijn   M   26   189.0    72.0     Netherlands
#
#     noc        games  year  season            city          sport  \
# 3   DEN  1900 Summer  1900  Summer           Paris     Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer       Antwerpen       Swimming
# 38  FIN  1920 Summer  1920  Summer       Antwerpen       Swimming
# 40  FIN  2014 Winter  2014  Winter           Sochi     Ice Hockey
# 41  FIN  1948 Summer  1948  Summer          London     Gymnastics
# 42  FIN  1948 Summer  1948  Summer          London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer          London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer          London     Gymnastics
# 50  FIN  1952 Summer  1952  Summer        Helsinki     Gymnastics
# 60  NOR  1992 Winter  1992  Winter     Albertville  Alpine Skiing
# 61  NOR  1992 Winter  1992  Winter     Albertville  Alpine Skiing
# 63  NOR  1994 Winter  1994  Winter     Lillehammer  Alpine Skiing
# 64  NOR  1994 Winter  1994  Winter     Lillehammer  Alpine Skiing
# 67  NOR  1994 Winter  1994  Winter     Lillehammer  Alpine Skiing
# 73  NOR  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
# 76  NOR  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
# 78  NOR  2006 Winter  2006  Winter          Torino  Alpine Skiing
# 79  NOR  2008 Summer  2008  Summer         Beijing       Handball
# 86  NOR  1920 Summer  1920  Summer       Antwerpen     Gymnastics
# 91  NED  1988 Summer  1988  Summer           Seoul         Hockey
# 92  NED  1996 Summer  1996  Summer         Atlanta         Rowing
#
#                                               event   medal
# 3                       Tug-Of-War Men's Tug-Of-War    Gold
# 37           Swimming Men's 200 metres Breaststroke  Bronze
# 38           Swimming Men's 400 metres Breaststroke  Bronze
# 40                      Ice Hockey Men's Ice Hockey  Bronze
# 41           Gymnastics Men's Individual All-Around  Bronze
# 42                 Gymnastics Men's Team All-Around    Gold
# 44                     Gymnastics Men's Horse Vault    Gold
# 48                 Gymnastics Men's Pommelled Horse    Gold
# 50                 Gymnastics Men's Team All-Around  Bronze
# 60                      Alpine Skiing Men's Super G    Gold
# 61                 Alpine Skiing Men's Giant Slalom  Bronze
# 63                     Alpine Skiing Men's Downhill  Silver
# 64                      Alpine Skiing Men's Super G  Bronze
# 67                     Alpine Skiing Men's Combined  Silver
# 73                      Alpine Skiing Men's Super G    Gold
# 76                     Alpine Skiing Men's Combined    Gold
# 78                      Alpine Skiing Men's Super G    Gold
# 79                        Handball Women's Handball    Gold
# 86  "Gymnastics Men's Team All-Around, Free System"  Silver
# 91                            Hockey Women's Hockey  Bronze
# 92           Rowing Men's Lightweight Double Sculls  Silver

# %%
df3 = df2.groupby("name").size()

# %% [markdown]
# Player name who has won most medals.

# %%
df3.idxmax()
# Out:
# 'Kjetil Andr Aamodt'

# %% [markdown]
# ## 9. List all events that include the term 'Freestyle' in their name

# %%
df[df["event"].str.contains("Freestyle")]
# Out:
#     id                              name sex  age  height  weight     team  \
# 29  10  Einar Ferdinand \Einari\" Aalto"   M   26     NaN     NaN  Finland
#
#     noc        games  year  season      city     sport  \
# 29  FIN  1952 Summer  1952  Summer  Helsinki  Swimming
#
#                                   event medal
# 29  Swimming Men's 400 metres Freestyle  None

# %% [markdown]
# ## 10. Find the top 3 athletes by the total number of medals won in each sport.

# %%
df3.sort_values(ascending=False).head(3)
# Out:
# name
# Kjetil Andr Aamodt         8
# Paavo Johannes Aaltonen    5
# Arvo Ossian Aaltonen       2
# dtype: int64

# %% [markdown]
# ## 11. List athletes who won more than one medal in a single Olympic year

# %%
df2.year.unique()
# Out:
# array([1900, 1920, 2014, 1948, 1952, 1992, 1994, 2002, 2006, 2008, 1988,
#        1996])

# %%
medals = df2.groupby(["name", "year"]).size().reset_index(name = "medalCount")

# %% [markdown]
# Athletes who won more than 1 medal in a single olympic year.

# %%
medals[medals["medalCount"] > 1]
# Out:
#                       name  year  medalCount
# 1     Arvo Ossian Aaltonen  1920           2
# 4       Kjetil Andr Aamodt  1992           2
# 5       Kjetil Andr Aamodt  1994           3
# 6       Kjetil Andr Aamodt  2002           2
# 8  Paavo Johannes Aaltonen  1948           4

# %% [markdown]
# ## 12. Identify countries that have won gold medals in both Summer and Winter Olympics (assuming a 'Season' column exists).

# %%
df2.groupby(["team", "season", "medal"]).size().unstack(fill_value=0)
# Out:
# medal                  Bronze  Gold  Silver
# team           season
# Denmark/Sweden Summer       0     1       0
# Finland        Summer       4     3       0
#                Winter       1     0       0
# Netherlands    Summer       1     0       1
# Norway         Summer       0     1       1
#                Winter       2     4       2

# %% [markdown]
# Norway is the only country which have won gold medals in both summer and winter olympics.

# %% [markdown]
# ## 13. Show the year difference between the first and last medal won by each country.

# %%
# first let's find the player who won silver medals.
df2.loc[df2["medal"] == "Silver"]
# Out:
#     id                name sex  age  height  weight         team  noc  \
# 63  20  Kjetil Andr Aamodt   M   22   176.0    85.0       Norway  NOR
# 67  20  Kjetil Andr Aamodt   M   22   176.0    85.0       Norway  NOR
# 86  25    Alf Lied Aanning   M   24     NaN     NaN       Norway  NOR
# 92  30    Pepijn Aardewijn   M   26   189.0    72.0  Netherlands  NED
#
#           games  year  season         city          sport  \
# 63  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 67  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 86  1920 Summer  1920  Summer    Antwerpen     Gymnastics
# 92  1996 Summer  1996  Summer      Atlanta         Rowing
#
#                                               event   medal
# 63                     Alpine Skiing Men's Downhill  Silver
# 67                     Alpine Skiing Men's Combined  Silver
# 86  "Gymnastics Men's Team All-Around, Free System"  Silver
# 92           Rowing Men's Lightweight Double Sculls  Silver

# %%
# Now finding for gold medal:
# 1. 
s1 = df2[df2["event"].str.contains(str(df2.loc[63, "event"])[:19])]
s1[s1["medal"] == "Gold"]
# Out:
#     id                name sex  age  height  weight    team  noc        games  \
# 60  20  Kjetil Andr Aamodt   M   20   176.0    85.0  Norway  NOR  1992 Winter
# 73  20  Kjetil Andr Aamodt   M   30   176.0    85.0  Norway  NOR  2002 Winter
# 76  20  Kjetil Andr Aamodt   M   30   176.0    85.0  Norway  NOR  2002 Winter
# 78  20  Kjetil Andr Aamodt   M   34   176.0    85.0  Norway  NOR  2006 Winter
#
#     year  season            city          sport                         event  \
# 60  1992  Winter     Albertville  Alpine Skiing   Alpine Skiing Men's Super G
# 73  2002  Winter  Salt Lake City  Alpine Skiing   Alpine Skiing Men's Super G
# 76  2002  Winter  Salt Lake City  Alpine Skiing  Alpine Skiing Men's Combined
# 78  2006  Winter          Torino  Alpine Skiing   Alpine Skiing Men's Super G
#
#    medal
# 60  Gold
# 73  Gold
# 76  Gold
# 78  Gold

# %% [markdown]
# So we have athlete Kjetil Andr Aamodt, who first won Silver and then Gold in the same game

# %%
# 2.
s2 = df2[df2["event"].str.contains(str(df2.loc[86, "event"])[:19])]
s2[s2["medal"] == "Gold"]   # no gold medals
# Out:
# Empty DataFrame
# Columns: [id, name, sex, age, height, weight, team, noc, games, year, season, city, sport, event, medal]
# Index: []

# %%
# 3.
s3 = df2[df2["event"].str.contains(str(df2.loc[92, "event"])[:19])]
s3[s3["medal"] == "Gold"]   # no gold medals
# Out:
# Empty DataFrame
# Columns: [id, name, sex, age, height, weight, team, noc, games, year, season, city, sport, event, medal]
# Index: []

# %% [markdown]
# ## 14. List countries that have won medals in more than 10 different sports.

# %%
s = df.groupby([ "team", "sport"]).size().reset_index(name = "medals")

# %%
s  # grouping the countries by sports
# Out:
#               team                 sport  medals
# 0            China            Basketball       1
# 1            China                  Judo       1
# 2          Denmark              Football       1
# 3   Denmark/Sweden            Tug-Of-War       1
# 4          Estonia             Athletics       1
# 5          Finland      Art Competitions       1
# 6          Finland             Athletics       1
# 7          Finland             Badminton       1
# 8          Finland              Biathlon       1
# 9          Finland  Cross Country Skiing       1
# 10         Finland            Gymnastics      16
# 11         Finland            Ice Hockey       2
# 12         Finland               Sailing       4
# 13         Finland              Swimming       6
# 14          France             Athletics       1
# 15     Netherlands             Athletics       2
# 16     Netherlands                Hockey       1
# 17     Netherlands                Rowing       2
# 18     Netherlands         Speed Skating       6
# 19     Netherlands            Water Polo       1
# 20          Norway         Alpine Skiing      20
# 21          Norway             Athletics       1
# 22          Norway             Bobsleigh       1
# 23          Norway            Gymnastics       1
# 24          Norway              Handball       1
# 25          Norway                  Luge       1
# 26          Norway               Sailing       2
# 27          Norway         Speed Skating       3
# 28          Norway             Wrestling       2
# 29         Romania         Weightlifting       1
# 30   United States  Cross Country Skiing      16

# %%
# Now finding unique sports for each country
s.groupby("team").size()
# Out:
# team
# China             2
# Denmark           1
# Denmark/Sweden    1
# Estonia           1
# Finland           9
# France            1
# Netherlands       5
# Norway            9
# Romania           1
# United States     1
# dtype: int64

# %% [markdown]
# From above data we can see that there is not a single country who have won medals in 10 different sports

# %% [markdown]
# ## 15. Find athletes who won medals in three consecutive Olympic games in the same event.

# %%
d = df.groupby(["event", "name", "year"]).size().reset_index(name="medal")
d
# Out:
#                                                 event  \
# 0   "Art Competitions Mixed Sculpturing, Unknown E...
# 1                      "Athletics Men's 1,500 metres"
# 2     "Gymnastics Men's Team All-Around, Free System"
# 3                  "Speed Skating Men's 1,500 metres"
# 4                  "Speed Skating Men's 1,500 metres"
# ..                                                ...
# 95             Swimming Men's 400 metres Breaststroke
# 96                Swimming Men's 400 metres Freestyle
# 97                        Tug-Of-War Men's Tug-Of-War
# 98                        Water Polo Men's Water Polo
# 99            Weightlifting Women's Super-Heavyweight
#
#                                   name  year  medal
# 0                Win Valdemar Aaltonen  1948      1
# 1   Jamale (Djamel-) Aarrass (Ahrass-)  2012      1
# 2                     Alf Lied Aanning  1920      1
# 3                     Nils Egil Aaness  1960      1
# 4                     Nils Egil Aaness  1964      1
# ..                                 ...   ...    ...
# 95                Arvo Ossian Aaltonen  1920      1
# 96    Einar Ferdinand \Einari\" Aalto"  1952      1
# 97                Edgar Lindenau Aabye  1900      1
# 98                       Johan Aantjes  1984      1
# 99                       Andreea Aanei  2016      1
#
# [100 rows x 4 columns]
